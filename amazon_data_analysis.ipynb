# %% [markdown]
# amazon data analysis

# %%
import requests

url = "https://real-time-amazon-data.p.rapidapi.com/seller-products"

querystring = {"seller_id":"A02211013Q5HP3OMSZC7W","country":"US","page":"1","sort_by":"RELEVANCE"}

headers = {
	"x-rapidapi-key": "9a623cdfcemsh9266ff7a3a527eap14f3d6jsnce6b2e1a1e5d",
	"x-rapidapi-host": "real-time-amazon-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()
print(data)
# Out:
# {'status': 'OK', 'request_id': 'c644be51-6511-492c-b9d0-728affd0ca18', 'parameters': {'seller_id': 'A02211013Q5HP3OMSZC7W', 'country': 'US', 'page': 1, 'sort_by': 'RELEVANCE'}, 'data': {'seller_id': 'A02211013Q5HP3OMSZC7W', 'total_products': 80, 'country': 'US', 'domain': 'www.amazon.com', 'seller_products': [{'asin': 'B09X7FXHVJ', 'product_title': 'SanDisk 128GB Extreme PRO SDXC UHS-I Memory Card - C10, U3, V30, 4K UHD, SD Card - SDSDXXD-128G-GN4IN', 'product_price': '$21.97', 'product_original_price': '$24.99', 'currency': 'USD', 'product_star_rating': '4.8', 'product_num_ratings': 58623, 'product_url': 'https://www.amazon.com/dp/B09X7FXHVJ', 'product_photo': 'https://m.media-amazon.com/images/I/81wwLOgkLgL._AC_UY654_FMwebp_QL65_.jpg', 'product_num_offers': 1, 'product_minimum_offer_price': '$21.97', 'is_best_seller': True, 'is_amazon_choice': False, 'is_prime': False, 'climate_pledge_friendly': False, 'sales_volume': '10K+ bought in past month', 'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7', 'has_variations': False, 'product_badge': 'Best Seller'}, {'asin': 'B08KSY222G', 'product_title': '32GB Ultra 100MBs Sandisk SDHC Memory Card', 'product_price': '$8.49', 'product_original_price': None, 'currency': 'USD', 'product_star_rating': '4.7', 'product_num_ratings': 1860, 'product_url': 'https://www.amazon.com/dp/B08KSY222G', 'product_photo': 'https://m.media-amazon.com/images/I/61QOQlB0RDL._AC_UY654_FMwebp_QL65_.jpg', 'product_num_offers': 1, 'product_minimum_offer_price': '$8.49', 'is_best_seller': False, 'is_amazon_choice': False, 'is_prime': False, 'climate_pledge_friendly': False, 'sales_volume': '10K+ bought in past month', 'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Wed, Jan 8', 'has_variations': False}, {'asin': 'B08J4HJ98L', 'product_title': 'SanDisk 32GB (Pack of 2) Ultra microSDHC UHS-I Memory Card (2x32GB) with Adapter - SDSQUA4-032G-GN6MT [New Version]', 'product_price': '$13.43', 'product_original_price': '$15.99', 'currency': 'USD', 'product_star_rating': '4.7', 'product_num_ratings': 183139, 'product_url': 'https://www.amazon.com/dp/B08J4HJ98L', 'product_photo': 'https://m.media-amazon.com/images/I/71TjonaVO6L._AC_UY654_FMwebp_QL65_.jpg', 'product_num_offers': 1, 'product_minimum_offer_price': '$13.43', 'is_best_seller': False, 'is_amazon_choice': False, 'is_prime': False, 'climate_pledge_friendly': False, 'sales_volume': '9K+ bought in past month', 'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Wed, Jan 8', 'has_variations': False}, {'asin': 'B08HSS37H7', 'product_title': 'SanDisk 32GB 3-Pack Ultra USB 3.0 Flash Drive 32GB (Pack of 3) - SDCZ48-032G-GAM46T, Black', 'product_price': '$17.29', 'unit_price': '$5.76', 'unit_count': 3, 'product_original_price': '$23.99', 'currency': 'USD', 'product_star_rating': '4.7', 'product_num_ratings': 42662, 'product_url': 'https://www.amazon.com/dp/B08HSS37H7', 'product_photo': 'https://m.media-amazon.com/images/I/71TUeg37CTL._AC_UY654_FMwebp_QL65_.jpg', 'product_num_offers': 1, 'product_minimum_offer_price': '$17.29', 'is_best_seller': False, 'is_amazon_choice': False, 'is_prime': False, 'climate_pledge_friendly': False, 'sales_volume': '7K+ bought in past month', 'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Wed, Jan 8', 'has_variations': False}, {'asin': 'B01EZ0X3L8', 'product_title': 'SanDisk 64GB Ultra Dual Drive USB Type-C - USB-C, USB 3.1 - SDDDC2-064G-G46, Grey/Silver', 'product_price': '$12.24', 'product_original_price': None, 'currency': 'USD', 'product_star_rating': '4.5', 'product_num_ratings': 107773, 'product_url': 'https://www.amazon.com/dp/B01EZ0X3L8', 'product_photo': 'https://m.media-amazon.com/images/I/41IUjBE4P2S._AC_UY654_FMwebp_QL65_.jpg', 'product_num_offers': 1, 'product_minimum_offer_price': '$12.24', 'is_best_seller': False, 'is_amazon_choice ...

# %%
data
# Out:
# {'status': 'OK',
#  'request_id': 'c644be51-6511-492c-b9d0-728affd0ca18',
#  'parameters': {'seller_id': 'A02211013Q5HP3OMSZC7W',
#   'country': 'US',
#   'page': 1,
#   'sort_by': 'RELEVANCE'},
#  'data': {'seller_id': 'A02211013Q5HP3OMSZC7W',
#   'total_products': 80,
#   'country': 'US',
#   'domain': 'www.amazon.com',
#   'seller_products': [{'asin': 'B09X7FXHVJ',
#     'product_title': 'SanDisk 128GB Extreme PRO SDXC UHS-I Memory Card - C10, U3, V30, 4K UHD, SD Card - SDSDXXD-128G-GN4IN',
#     'product_price': '$21.97',
#     'product_original_price': '$24.99',
#     'currency': 'USD',
#     'product_star_rating': '4.8',
#     'product_num_ratings': 58623,
#     'product_url': 'https://www.amazon.com/dp/B09X7FXHVJ',
#     'product_photo': 'https://m.media-amazon.com/images/I/81wwLOgkLgL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$21.97',
#     'is_best_seller': True,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '10K+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7',
#     'has_variations': False,
#     'product_badge': 'Best Seller'},
#    {'asin': 'B08KSY222G',
#     'product_title': '32GB Ultra 100MBs Sandisk SDHC Memory Card',
#     'product_price': '$8.49',
#     'product_original_price': None,
#     'currency': 'USD',
#     'product_star_rating': '4.7',
#     'product_num_ratings': 1860,
#     'product_url': 'https://www.amazon.com/dp/B08KSY222G',
#     'product_photo': 'https://m.media-amazon.com/images/I/61QOQlB0RDL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$8.49',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '10K+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Wed, Jan 8',
#     'has_variations': False},
#    {'asin': 'B08J4HJ98L',
#     'product_title': 'SanDisk 32GB (Pack of 2) Ultra microSDHC UHS-I Memory Card (2x32GB) with Adapter - SDSQUA4-032G-GN6MT [New Version]',
#     'product_price': '$13.43',
#     'product_original_price': '$15.99',
#     'currency': 'USD',
#     'product_star_rating': '4.7',
#     'product_num_ratings': 183139,
#     'product_url': 'https://www.amazon.com/dp/B08J4HJ98L',
#     'product_photo': 'https://m.media-amazon.com/images/I/71TjonaVO6L._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$13.43',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '9K+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Wed, Jan 8',
#     'has_variations': False},
#    {'asin': 'B08HSS37H7',
#     'product_title': 'SanDisk 32GB 3-Pack Ultra USB 3.0 Flash Drive 32GB (Pack of 3) - SDCZ48-032G-GAM46T, Black',
#     'product_price': '$17.29',
#     'unit_price': '$5.76',
#     'unit_count': 3,
#     'product_original_price': '$23.99',
#     'currency': 'USD',
#     'product_star_rating': '4.7',
#     'product_num_ratings': 42662,
#     'product_url': 'https://www.amazon.com/dp/B08HSS37H7',
#     'product_photo': 'https://m.media-amazon.com/images/I/71TUeg37CTL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$17.29',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '7K+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Wed, Jan 8',
#     'has_variations': False},
#    {'asin': 'B01EZ0X3L8',
#     'product_title': 'SanDisk 64GB Ultra Dual Drive USB Type-C - USB-C, USB 3.1 - SDDDC2-064G-G46, Grey/Silver',
#     'product_price': '$12.24',
#     'product_original_price': None,
#     'currency': 'USD',
#     'product_star_rating': '4.5',
#     'product_num_ratings': 107773,
#     'product_url': 'https://www.amazon.com/dp/B01EZ0X3L8',
#     'product_photo': 'https://m.media-amazon.com/images/I/41IUjBE4P2S._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$12.24',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '1K+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7',
#     'has_variations': False},
#    {'asin': 'B09LH5SBPS',
#     'product_title': 'Raspberry Pi Zero 2 W (Wireless / Bluetooth) 2021 (RPi Zero 2W)',
#     'product_price': '$22.49',
#     'product_original_price': '$24.99',
#     'currency': 'USD',
#     'product_star_rating': '4.7',
#     'product_num_ratings': 557,
#     'product_url': 'https://www.amazon.com/dp/B09LH5SBPS',
#     'product_photo': 'https://m.media-amazon.com/images/I/61rVLsPzmeL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$22.49',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '1K+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7',
#     'has_variations': False},
#    {'asin': 'B001W1BSM0',
#     'product_title': 'SanDisk Flash 16 GB SDHC Flash Memory Card SDSDB-016G (Label May Change)',
#     'product_price': '$7.21',
#     'product_original_price': '$11.99',
#     'currency': 'USD',
#     'product_star_rating': '4.6',
#     'product_num_ratings': 41958,
#     'product_url': 'https://www.amazon.com/dp/B001W1BSM0',
#     'product_photo': 'https://m.media-amazon.com/images/I/71jpJNjAxLS._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$7.21',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '500+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7',
#     'has_variations': False},
#    {'asin': 'B07G5JV2B5',
#     'product_title': 'SanDisk MobileMate USB 3.0 microSD Card Reader- SDDR-B531-GN6NN',
#     'product_price': '$9.41',
#     'product_original_price': '$12.99',
#     'currency': 'USD',
#     'product_star_rating': '4.5',
#     'product_num_ratings': 30924,
#     'product_url': 'https://www.amazon.com/dp/B07G5JV2B5',
#     'product_photo': 'https://m.media-amazon.com/images/I/51sXyOOG+6L._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$9.41',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '2K+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7',
#     'has_variations': False},
#    {'asin': 'B07TC2BK1X',
#     'product_title': 'Raspberry Pi 4 Model B 2019 Quad Core 64 Bit WiFi Bluetooth (4GB)',
#     'product_price': '$65.99',
#     'product_original_price': None,
#     'currency': 'USD',
#     'product_star_rating': '4.7',
#     'product_num_ratings': 18709,
#     'product_url': 'https://www.amazon.com/dp/B07TC2BK1X',
#     'product_photo': 'https://m.media-amazon.com/images/I/71A14Sz2bWL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$65.99',
#     'is_best_seller': True,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '1K+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11Or fastest delivery Tomorrow, Jan 7',
#     'has_variations': False,
#     'product_badge': 'Best Seller'},
#    {'asin': 'B07YYJL21Z',
#     'product_title': 'SanDisk 256GB Ultra Dual Drive Go USB Type-C Flash Drive, Black - SDDDC3-256G-G46',
#     'product_price': '$23.82',
#     'product_original_price': None,
#     'currency': 'USD',
#     'product_star_rating': '4.4',
#     'product_num_ratings': 28404,
#     'product_url': 'https://www.amazon.com/dp/B07YYJL21Z',
#     'product_photo': 'https://m.media-amazon.com/images/I/71qOWNxv4jL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$23.82',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '500+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7',
#     'has_variations': False},
#    {'asin': 'B07855LJ99',
#     'product_title': 'SanDisk 128GB Ultra Fit USB 3.1 Flash Drive - SDCZ430-128G-G46',
#     'product_price': '$14.04',
#     'product_original_price': None,
#     'currency': 'USD',
#     'product_star_rating': '4.5',
#     'product_num_ratings': 72450,
#     'product_url': 'https://www.amazon.com/dp/B07855LJ99',
#     'product_photo': 'https://m.media-amazon.com/images/I/81WJgkjTGML._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$14.04',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '300+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7',
#     'has_variations': False},
#    {'asin': 'B013TMNPBQ',
#     'product_title': 'Made for Amazon SanDisk 128GB microSD Memory Card for Fire Tablets and Fire -TV',
#     'product_price': '$13.81',
#     'product_original_price': None,
#     'currency': 'USD',
#     'product_star_rating': '4.6',
#     'product_num_ratings': 91511,
#     'product_url': 'https://www.amazon.com/dp/B013TMNPBQ',
#     'product_photo': 'https://m.media-amazon.com/images/I/81dQGd03YHL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$13.81',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '10K+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Wed, Jan 8',
#     'has_variations': False},
#    {'asin': 'B0CWPNB3M7',
#     'product_title': 'SAMSUNG EVO Plus microSD Memory Card + Adapter, 512GB microSDXC, Speeds Up to 160 MB/s, UHS-I, C10, U3, V10, A3, Upgrade Storage for Phones, Tablets, Gaming Consoles, DSLR Cameras, PCs, MB-MC512SA/AM',
#     'product_price': '$47.42',
#     'product_original_price': '$60.99',
#     'currency': 'USD',
#     'product_star_rating': '4.6',
#     'product_num_ratings': 166,
#     'product_url': 'https://www.amazon.com/dp/B0CWPNB3M7',
#     'product_photo': 'https://m.media-amazon.com/images/I/71JLnMxeIkL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$47.42',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '300+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11Or fastest delivery Tomorrow, Jan 7',
#     'has_variations': False},
#    {'asin': 'B0143IIP4W',
#     'product_title': 'SanDisk Ultra 64GB Class 10 SDXC UHS-I Memory Card up to 80MB/s (SDSDUNC-064G-GN6IN)',
#     'product_price': '$9.99',
#     'product_original_price': None,
#     'currency': 'USD',
#     'product_star_rating': '4.7',
#     'product_num_ratings': 118025,
#     'product_url': 'https://www.amazon.com/dp/B0143IIP4W',
#     'product_photo': 'https://m.media-amazon.com/images/I/71-9vJst-lL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$9.99',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'product_availability': 'Only 3 left in stock - order soon.',
#     'climate_pledge_friendly': False,
#     'sales_volume': '1K+ bought in past month',
#     'delivery': 'FREE delivery on $35.00 of items shipped by AmazonOnly 3 left in stock - order soon.',
#     'has_variations': False},
#    {'asin': 'B00UKKBAE0',
#     'product_title': 'P-A000146N - 6&quot; Extension Cord with Flat Rotating Plug - Black',
#     'product_price': '$12.99',
#     'product_original_price': None,
#     'currency': 'USD',
#     'product_star_rating': '4.7',
#     'product_num_ratings': 1628,
#     'product_url': 'https://www.amazon.com/dp/B00UKKBAE0',
#     'product_photo': 'https://m.media-amazon.com/images/I/51wYCrspGiL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$12.99',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': True,
#     'sales_volume': '200+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7',
#     'has_variations': False},
#    {'asin': 'B000FGNM6I',
#     'product_title': 'Transcend 2 GB SD Flash Memory Card (TS2GSDC)',
#     'product_price': '$9.68',
#     'product_original_price': '$22.00',
#     'currency': 'USD',
#     'product_star_rating': '4.7',
#     'product_num_ratings': 7255,
#     'product_url': 'https://www.amazon.com/dp/B000FGNM6I',
#     'product_photo': 'https://m.media-amazon.com/images/I/510i8wqyufL._AC_UY654_FMwebp_QL65_.jpg',
#     'product_num_offers': 1,
#     'product_minimum_offer_price': '$9.68',
#     'is_best_seller': False,
#     'is_amazon_choice': False,
#     'is_prime': False,
#     'climate_pledge_friendly': False,
#     'sales_volume': '500+ bought in past month',
#     'delivery': 'FREE delivery Sat, Jan 11 on $35.00 of items shipped by AmazonOr fastest delivery Tomorrow, Jan 7',
#     'has_variations': False}]}}
